# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt  
import seaborn as sns
from matplotlib import style

# %%
train_X = pd.read_csv(
    "data/train_feature.csv",
    index_col="id"
)

train_Y = pd.read_csv(
    "data/train_labels.csv",
    index_col="id"
)

test = pd.read_csv(
    "data/test.csv",
    index_col="id"
)

# %%
labels = train_Y['status_group'].value_counts()
print(labels)
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %%
train_X.isnull().sum()[train_X.isnull().sum()>0]
# Out:
# funder                3635
# installer             3655
# subvillage             371
# public_meeting        3334
# scheme_management     3877
# scheme_name          28166
# permit                3056
# dtype: int64

# %%
pd.options.display.max_columns = 40
summary = train_X.describe(include='all')
summary
# Out:
#            amount_tsh date_recorded                  funder    gps_height  \
# count    59400.000000         59400                   55765  59400.000000
# unique            NaN           356                    1897           NaN
# top               NaN    2011-03-15  Government Of Tanzania           NaN
# freq              NaN           572                    9084           NaN
# mean       317.650385           NaN                     NaN    668.297239
# std       2997.574558           NaN                     NaN    693.116350
# min          0.000000           NaN                     NaN    -90.000000
# 25%          0.000000           NaN                     NaN      0.000000
# 50%          0.000000           NaN                     NaN    369.000000
# 75%         20.000000           NaN                     NaN   1319.250000
# max     350000.000000           NaN                     NaN   2770.000000
#
#        installer     longitude      latitude wpt_name   num_private  \
# ...

# %%
correlation_matrix = train_X.corr()
correlation_matrix
# Out:
#                    amount_tsh  gps_height  longitude  latitude  num_private  \
# amount_tsh           1.000000    0.076650   0.022134 -0.052670     0.002944
# gps_height           0.076650    1.000000   0.149155 -0.035751     0.007237
# longitude            0.022134    0.149155   1.000000 -0.425802     0.023873
# latitude            -0.052670   -0.035751  -0.425802  1.000000     0.006837
# num_private          0.002944    0.007237   0.023873  0.006837     1.000000
# region_code         -0.026813   -0.183521   0.034197 -0.221018    -0.020377
# district_code       -0.023599   -0.171233   0.151398 -0.201020    -0.004478
# population           0.016288    0.135003   0.086590 -0.022152     0.003818
# construction_year    0.067915    0.658727   0.396732 -0.245278     0.026056
#
#                    region_code  district_code  population  construction_year
# amount_tsh           -0.026813      -0.023599    0.016288           0.067915
# ...

# %%
fig = plt.figure(figsize=(8,8))
r = sns.heatmap(correlation_matrix, cmap="Greens")
r.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

# %%
train_and_labels = train_X.copy()
train_and_labels['status_group'] = train_Y['status_group']
train_and_labels
# Out:
#        amount_tsh date_recorded           funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14            Roman        1390         Roman
# 8776          0.0    2013-03-06          Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25     Lottery Club         686  World vision
# 67743         0.0    2013-01-28           Unicef         263        UNICEF
# 19728         0.0    2011-07-13      Action In A           0       Artisan
# ...           ...           ...              ...         ...           ...
# 60739        10.0    2013-05-03  Germany Republi        1210           CES
# 27263      4700.0    2011-05-07      Cefa-njombe        1212          Cefa
# 37057         0.0    2011-04-11              NaN           0           NaN
# 31282         0.0    2011-03-08            Malec           0          Musa
# 26348         0.0    2011-03-23       World Bank         191         World
#
# ...

# %%
sns.relplot(
    x="longitude", y="latitude", hue="status_group", data=train_and_labels, height=6,
);

# %%
def replace_with_median(data):
    region_median = data.groupby(['region_code'])[['latitude', 'longitude']].median()
    def geo_update(row, df_geo):
        row['longitude'] = df_geo.loc[row['region_code']]['longitude']
        row['latitude'] = df_geo.loc[row['region_code']]['latitude']
        return row

    data.loc[data['longitude']==0, ['longitude', 'latitude']] = \
        data[data['longitude']==0].apply(
            geo_update, df_geo=region_median, axis=1)[['longitude', 'latitude']]

# %%
replace_with_median(train_and_labels)

# %%
sns.relplot(
    x="longitude", y="latitude", hue="status_group", data=train_and_labels, height=6,
);

# %%
def replace_with_mode(data):
    df_scheme = data.groupby(['region'])['scheme_name'].agg(pd.Series.mode)
    
    def scheme_update(row, df_scheme):
        row['scheme_name'] = df_scheme[row['region']]
        return row

    df.loc[df['scheme_name'].isnull(), ['scheme_name']] = \
        df[df['scheme_name'].isnull()].apply(
            scheme_update, df_scheme=df_scheme, axis=1)[['scheme_name']]

# %%
 train_X.loc[train_X['longitude']==0]
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 6091          0.0    2013-02-10                    Dwsp           0
# 32376         0.0    2011-08-01  Government Of Tanzania           0
# 72678         0.0    2013-01-30                     Wvt           0
# 56725         0.0    2013-01-17             Netherlands           0
# 13042         0.0    2012-10-29                  Hesawa           0
# ...           ...           ...                     ...         ...
# 62177         0.0    2011-07-18                    Dwsp           0
# 3631          0.0    2013-01-22                    Dwsp           0
# 60843         0.0    2011-07-19                   Rwssp           0
# 748           0.0    2013-01-22            World Vision           0
# 49651         0.0    2012-10-29                   Rwssp           0
#
#           installer  longitude      latitude                 wpt_name  \
# id
# ...
